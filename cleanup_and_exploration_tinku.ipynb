# %% [markdown]
# # Austin B-cycle Data Cleanup and Exploration

# %% [markdown]
# ##  Dependencies and Read CSV
#
# * API https://data.austintexas.gov/Transportation-and-Mobility/Austin-B-Cycle-Trips/tyfh-5r8s
#
# * Data Available
#     * Trip ID
#     * Membership Type
#     * Bicycle ID
#     * Checkout Time
#     * Checkout Kiosk ID
#     * Checkout Kiosk
#     * Return Kiosk ID
#     * Trip Duration Minutes
#     * Month
#     * Year

# %%
# Uncomment the command below if sodapy is not currently installed 
#!pip uninstall sodapy

# %%
# Import Dependencies
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import csv
import requests
from pprint import pprint
from sodapy import Socrata

# Ignore Warnings as we are rewrititng values 
import warnings
warnings.filterwarnings('ignore')

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.austintexas.gov", None)

# First 991271 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("cwi3-ckqi", limit= 991271)

# Convert to pandas DataFrame
df_bike= pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
# Display the top rows of the dataframe 
df_bike.head()
# Out:
#   bicycle_id            checkout_date  \
# 0        207  2014-10-26T00:00:00.000
# 1        969  2014-10-26T00:00:00.000
# 2        214  2014-10-26T00:00:00.000
# 3        745  2014-10-26T00:00:00.000
# 4        164  2014-10-26T00:00:00.000
#
#                                       checkout_kiosk checkout_kiosk_id  \
# 0                                     West & 6th St.              2537
# 1            Convention Center / 4th St. @ MetroRail              2498
# 2                                     West & 6th St.              2537
# 3  Zilker Park at Barton Springs & William Barton...               NaN
# 4                    Bullock Museum @ Congress & MLK              2538
#
#   checkout_time                     membership_type month  \
# 0      13:12:00        Annual (San Antonio B-cycle)    10
# 1      13:12:00      24-Hour Kiosk (Austin B-cycle)    10
# 2      13:12:00  Annual Membership (Austin B-cycle)    10
# 3      13:12:00      24-Hour Kiosk (Austin B-cycle)    10
# 4      13:12:00      24-Hour Kiosk (Austin B-cycle)    10
#
#                                         return_kiosk return_kiosk_id  \
# 0                               Rainey St @ Cummings            2707
# 1                      Pfluger Bridge @ W 2nd Street            2566
# 2                                     8th & Congress            2496
# 3  Zilker Park at Barton Springs & William Barton...             NaN
# 4                   Convention Center/ 3rd & Trinity             NaN
#
#   trip_duration_minutes     trip_id  year
# 0                    76  9900285854  2014
# 1                    58  9900285855  2014
# 2                     8  9900285856  2014
# 3                    28  9900285857  2014
# 4                    15  9900285858  2014

# %% [markdown]
# ## Initial Data Exploration
#
# On an initial exploration of the data we see that the columns month, year, membership type, bicycle id, return kiosk id, and check out kiosk id are missing values. It does not necessarily mean that the data is not present. It just needs to be extracted and reformatted.

# %%
# Count rows and columns 
df_bike.shape
# Out:
# (991271, 12)

# %%
# Check for missing values 
df_bike.count()
# Out:
# bicycle_id               990548
# checkout_date            991271
# checkout_kiosk           991271
# checkout_kiosk_id        972240
# checkout_time            991271
# membership_type          984960
# month                    618479
# return_kiosk             991271
# return_kiosk_id          971487
# trip_duration_minutes    991271
# trip_id                  991271
# year                     618479
# dtype: int64

# %%
# We see that the last values of our dataframe are missing the month and year
df_bike.tail()
# Out:
#        bicycle_id            checkout_date  \
# 991266       1524  2018-07-31T00:00:00.000
# 991267         95  2018-07-31T00:00:00.000
# 991268        252  2018-07-31T00:00:00.000
# 991269       2228  2018-07-31T00:00:00.000
# 991270        576  2018-07-31T00:00:00.000
#
#                              checkout_kiosk checkout_kiosk_id checkout_time  \
# 991266    Capitol Station / Congress & 11th              2497      23:24:32
# 991267  Long Center @ South 1st & Riverside              2549      23:29:21
# 991268                    Rio Grande & 28th              3793      23:39:16
# 991269                 Dean Keeton & Whitis              3795      23:42:50
# 991270                    Rio Grande & 28th              3793      23:44:32
#
#                 membership_type month               return_kiosk  \
# 991266  U.T. Student Membership   NaN   City Hall / Lavaca & 2nd
# 991267      Local365+Guest Pass   NaN  East 6th & Pedernales St.
# 991268  U.T. Student Membership   NaN               22nd & Pearl
# 991269  U.T. Student Membership   NaN              Nueces & 26th
# 991270  U.T. Student Membership   NaN          Rio Grande & 28th
#
#        return_kiosk_id trip_duration_minutes   trip_id year
# 991266            2499                    29  18122309  NaN
# 991267            2544                    18  18122312  NaN
# 991268            3792                     4  18122330  NaN
# 991269            3838                     2  18122340  NaN
# 991270            3793                     4  18122349  NaN

# %%
# Count how many rows are missing year, month, membership_type, bicycle_id 
missing_year = df_bike["year"].isnull().sum()
missing_month = df_bike["month"].isnull().sum()
missing_membership_type = df_bike["membership_type"].isnull().sum()
missing_bike_id = df_bike["bicycle_id"].isnull().sum()

# Create summary table of the missing values 
print(f"There are {missing_year} missing year values.")
print(f"There are {missing_month} missing month values.")
print(f"There are {missing_membership_type} missing membership type values.")
print(f"There are {missing_bike_id} missing bike id values.")
# Out:
# There are 372792 missing year values.
# There are 372792 missing month values.
# There are 6311 missing membership type values.
# There are 723 missing bike id values.

# %%
df_bike.dtypes
# Out:
# bicycle_id               object
# checkout_date            object
# checkout_kiosk           object
# checkout_kiosk_id        object
# checkout_time            object
# membership_type          object
# month                    object
# return_kiosk             object
# return_kiosk_id          object
# trip_duration_minutes    object
# trip_id                  object
# year                     object
# dtype: object

# %% [markdown]
# ## Initial Data Clean Up
#
# In this section we create a new data frame with the needed values.
# 1.	Since we are missing kiosk ID's but we have the kiosk names available, we can make a new data frame without having to drop the rows of missing kiosk id's.
#
# 2.	We need to extract the year, month and date from check out date, to fill in the missing values in the Month and Year column.
#
# 3.	We can extract the hour from Check Out time for future analysis.

# %%
# renaming the data frame
df_bike_clean = df_bike

# %%
# So now we see that we have a check out date that matches the number of trips taken 
df_bike_clean.count()
# Out:
# bicycle_id               990548
# checkout_date            991271
# checkout_kiosk           991271
# checkout_kiosk_id        972240
# checkout_time            991271
# membership_type          984960
# month                    618479
# return_kiosk             991271
# return_kiosk_id          971487
# trip_duration_minutes    991271
# trip_id                  991271
# year                     618479
# dtype: int64

# %%
# We see take the Checkout Date and extract the Month, Year, and Day of the Week 

df_bike_clean['Checkout Date'] = pd.to_datetime(df_bike_clean['checkout_date']) 
df_bike_clean['Year'] = df_bike_clean['Checkout Date'].dt.year
df_bike_clean['Month'] = df_bike_clean['Checkout Date'].dt.month
df_bike_clean['Trip Date'] = df_bike_clean['Checkout Date'].dt.day
df_bike_clean['Trip Day of Week'] = df_bike_clean['Checkout Date'].dt.weekday_name

# %%
# Inspect the filled in values 
df_bike_clean.tail()
# Out:
#        bicycle_id            checkout_date  \
# 991266       1524  2018-07-31T00:00:00.000
# 991267         95  2018-07-31T00:00:00.000
# 991268        252  2018-07-31T00:00:00.000
# 991269       2228  2018-07-31T00:00:00.000
# 991270        576  2018-07-31T00:00:00.000
#
#                              checkout_kiosk checkout_kiosk_id checkout_time  \
# 991266    Capitol Station / Congress & 11th              2497      23:24:32
# 991267  Long Center @ South 1st & Riverside              2549      23:29:21
# 991268                    Rio Grande & 28th              3793      23:39:16
# 991269                 Dean Keeton & Whitis              3795      23:42:50
# 991270                    Rio Grande & 28th              3793      23:44:32
#
#                 membership_type month               return_kiosk  \
# 991266  U.T. Student Membership   NaN   City Hall / Lavaca & 2nd
# 991267      Local365+Guest Pass   NaN  East 6th & Pedernales St.
# 991268  U.T. Student Membership   NaN               22nd & Pearl
# 991269  U.T. Student Membership   NaN              Nueces & 26th
# 991270  U.T. Student Membership   NaN          Rio Grande & 28th
#
#        return_kiosk_id trip_duration_minutes   trip_id year Checkout Date  \
# 991266            2499                    29  18122309  NaN    2018-07-31
# 991267            2544                    18  18122312  NaN    2018-07-31
# 991268            3792                     4  18122330  NaN    2018-07-31
# 991269            3838                     2  18122340  NaN    2018-07-31
# 991270            3793                     4  18122349  NaN    2018-07-31
#
#         Year  Month  Trip Date Trip Day of Week
# 991266  2018      7         31          Tuesday
# 991267  2018      7         31          Tuesday
# 991268  2018      7         31          Tuesday
# 991269  2018      7         31          Tuesday
# 991270  2018      7         31          Tuesday

# %%
# Split the hour from the checkout time
checkout_time = pd.to_datetime(df_bike_clean['checkout_time'],infer_datetime_format=True)
df_bike_clean['time'] = checkout_time.dt.time
df_bike_clean['Trip Hour'] = checkout_time.dt.hour
df_bike_clean.drop(columns='time',inplace = True)
df_bike_clean.head(1)
# Out:
#   bicycle_id            checkout_date  checkout_kiosk checkout_kiosk_id  \
# 0        207  2014-10-26T00:00:00.000  West & 6th St.              2537
#
#   checkout_time               membership_type month          return_kiosk  \
# 0      13:12:00  Annual (San Antonio B-cycle)    10  Rainey St @ Cummings
#
#   return_kiosk_id trip_duration_minutes     trip_id  year Checkout Date  Year  \
# 0            2707                    76  9900285854  2014    2014-10-26  2014
#
#    Month  Trip Date Trip Day of Week  Trip Hour
# 0     10         26           Sunday         13

# %%
# Inspect the filled in values 
df_bike_clean.head()
# Out:
#   bicycle_id            checkout_date  \
# 0        207  2014-10-26T00:00:00.000
# 1        969  2014-10-26T00:00:00.000
# 2        214  2014-10-26T00:00:00.000
# 3        745  2014-10-26T00:00:00.000
# 4        164  2014-10-26T00:00:00.000
#
#                                       checkout_kiosk checkout_kiosk_id  \
# 0                                     West & 6th St.              2537
# 1            Convention Center / 4th St. @ MetroRail              2498
# 2                                     West & 6th St.              2537
# 3  Zilker Park at Barton Springs & William Barton...               NaN
# 4                    Bullock Museum @ Congress & MLK              2538
#
#   checkout_time                     membership_type month  \
# 0      13:12:00        Annual (San Antonio B-cycle)    10
# 1      13:12:00      24-Hour Kiosk (Austin B-cycle)    10
# 2      13:12:00  Annual Membership (Austin B-cycle)    10
# 3      13:12:00      24-Hour Kiosk (Austin B-cycle)    10
# 4      13:12:00      24-Hour Kiosk (Austin B-cycle)    10
#
#                                         return_kiosk return_kiosk_id  \
# 0                               Rainey St @ Cummings            2707
# 1                      Pfluger Bridge @ W 2nd Street            2566
# 2                                     8th & Congress            2496
# 3  Zilker Park at Barton Springs & William Barton...             NaN
# 4                   Convention Center/ 3rd & Trinity             NaN
#
#   trip_duration_minutes     trip_id  year Checkout Date  Year  Month  \
# 0                    76  9900285854  2014    2014-10-26  2014     10
# 1                    58  9900285855  2014    2014-10-26  2014     10
# 2                     8  9900285856  2014    2014-10-26  2014     10
# 3                    28  9900285857  2014    2014-10-26  2014     10
# 4                    15  9900285858  2014    2014-10-26  2014     10
#
#    Trip Date Trip Day of Week  Trip Hour
# 0         26           Sunday         13
# 1         26           Sunday         13
# 2         26           Sunday         13
# 3         26           Sunday         13
# 4         26           Sunday         13

# %%
# Check for missing values 
df_bike_clean.count()
# Out:
# bicycle_id               990548
# checkout_date            991271
# checkout_kiosk           991271
# checkout_kiosk_id        972240
# checkout_time            991271
# membership_type          984960
# month                    618479
# return_kiosk             991271
# return_kiosk_id          971487
# trip_duration_minutes    991271
# trip_id                  991271
# year                     618479
# Checkout Date            991271
# Year                     991271
# Month                    991271
# Trip Date                991271
# Trip Day of Week         991271
# Trip Hour                991271
# dtype: int64

# %%
# Verify Data types
df_bike_clean.dtypes
# Out:
# bicycle_id                       object
# checkout_date                    object
# checkout_kiosk                   object
# checkout_kiosk_id                object
# checkout_time                    object
# membership_type                  object
# month                            object
# return_kiosk                     object
# return_kiosk_id                  object
# trip_duration_minutes            object
# trip_id                          object
# year                             object
# Checkout Date            datetime64[ns]
# Year                              int64
# Month                             int64
# Trip Date                         int64
# Trip Day of Week                 object
# Trip Hour                         int64
# dtype: object

# %%
## converting trip duration minutes from object to integer
df_bike_change1 = df_bike_clean["trip_duration_minutes"].astype(int)
df_bike_clean["trip_duration_minutes"] = df_bike_change1

# %%
df_bike_clean.dtypes
# Out:
# bicycle_id                       object
# checkout_date                    object
# checkout_kiosk                   object
# checkout_kiosk_id                object
# checkout_time                    object
# membership_type                  object
# month                            object
# return_kiosk                     object
# return_kiosk_id                  object
# trip_duration_minutes             int32
# trip_id                          object
# year                             object
# Checkout Date            datetime64[ns]
# Year                              int64
# Month                             int64
# Trip Date                         int64
# Trip Day of Week                 object
# Trip Hour                         int64
# dtype: object

# %%
## Renaming the Columns Name

df_bike_clean = df_bike_clean.rename(columns = {
    "bicycle_id": "Bicycle ID",
    "checkout_date": "Checkout Date",
    "checkout_kiosk": "Checkout Station",
    "checkout_kiosk_id": "Checkout Station ID",
    "checkout_time": "Checkout Time",
    "membership_type": "Membership Type",
    "month": "Trip Month",
    "return_kiosk":"Return Station",
    "return_kiosk_id": "Return Station ID",
    "trip_duration_minutes": "Trip Duration Minutes",
    "trip_id": "Trip ID",
    "year":"Trip Year",
    "Checkout Kiosk ID":"Checkout Station ID"
                                         })

df_bike_clean.head(1)
# Out:
#   Bicycle ID            Checkout Date Checkout Station Checkout Station ID  \
# 0        207  2014-10-26T00:00:00.000   West & 6th St.                2537
#
#   Checkout Time               Membership Type Trip Month  \
# 0      13:12:00  Annual (San Antonio B-cycle)         10
#
#          Return Station Return Station ID  Trip Duration Minutes     Trip ID  \
# 0  Rainey St @ Cummings              2707                     76  9900285854
#
#   Trip Year Checkout Date  Year  Month  Trip Date Trip Day of Week  Trip Hour
# 0      2014    2014-10-26  2014     10         26           Sunday         13

# %% [markdown]
# ## Cleaning the column Trip Duration
#
# But we are not dropping the rows for our final clean csv file because even in these rows the Trip IDs are correct which we can use to count number of rides made for our analysis for other columns

# %%
# To check how many bikes were stolen
# These bikes have unusally large trip duration
df_bike_stolen = df_bike_clean.loc[df_bike_clean["Return Station"] == "Stolen"]
number_bike_stolen = df_bike_stolen["Return Station"].count()


# To check how many bikes were missing
# These bikes have unusally large trip duration
df_bike_missing = df_bike_clean.loc[df_bike_clean["Return Station"] == "Missing"]
number_bike_missing = df_bike_missing["Return Station"].count()


# To check how many bikes have trip duration has zero minutes
df_bike_trip_minutes_zero = df_bike_clean.loc[df_bike_clean["Trip Duration Minutes"] == 0]
number_bike_trip_minutes_zero = df_bike_trip_minutes_zero["Trip ID"].count()

# Summary of bike trips with distinict data 
print(f"There are {number_bike_stolen} bikes reported as stolen.")
print(f"There are {number_bike_missing} bikes reported as missing.")
print(f"There are {number_bike_trip_minutes_zero} bikes that had a trip duration of zero.")
# Out:
# There are 23 bikes reported as stolen.
# There are 25 bikes reported as missing.
# There are 19033 bikes that had a trip duration of zero.

# %% [markdown]
# ## Cleaning and data exploration of the Checkout Station ID and Checkout Station Column
#
# But we are not dropping the rows for our final clean csv file because even in these rows the Trip IDs are correct which we can use to count number of rides made for our analysis for other columns

# %%
# To check how many Checkout Station ID are blank
number_df_bike_checkout_id_blank  = df_bike_clean["Checkout Station ID"].isnull().sum()
print(f"There are {number_df_bike_checkout_id_blank} Checkout Station IDs that are blank.")
# Out:
# There are 19031 Checkout Station IDs that are blank.

# %%
# Filling the Na values with zero for exploration
df_bike_na = df_bike_clean.fillna(0)

# %%
## To find which check out station have blank checkout IDs that is zero or #N/A
df_bike_checkout_id_blank = df_bike_na.loc[(df_bike_na["Checkout Station ID"] == 0) | (df_bike_na["Checkout Station ID"] == "#N/A")]
df_bike_checkout_id_blank["Checkout Station"].value_counts()
# Out:
# Zilker Park at Barton Springs & William Barton Drive    11534
# Dean Keeton & Speedway                                   3825
# ACC - West & 12th                                        2462
# Convention Center/ 3rd & Trinity                         1292
# Mobile Station                                           1183
# East 11th Street at Victory Grill                        1030
# Red River @ LBJ Library                                   584
# Mobile Station @ Bike Fest                                516
# Main Office                                               300
# Bullock Museum @ Congress & MLK                           172
# State Capitol @ 14th & Colorado                           111
# MapJam at Pan Am Park                                      32
# MapJam at French Legation                                  27
# MapJam at Hops & Grain Brewery                             19
# Repair Shop                                                15
# MapJam at Scoot Inn                                        11
# Shop                                                       10
# Mobile Station @ Boardwalk Opening Ceremony                 9
# Re-branding                                                 7
# Mobile Station @ Unplugged                                  4
# Customer Service                                            4
# Marketing Event                                             4
# Eeyore's 2018                                               2
# Eeyore's 2017                                               1
# Name: Checkout Station, dtype: int64

# %%
## list of checkout station id
checkout_station_id_list =  df_bike_na["Checkout Station ID"].value_counts().index
checkout_station_id_list

## we have 83 unique check out station ID excluding zero and #N/A
# Out:
# Index(['3798', '2575', '2499', '2494', '2501', '2707', '2495', '2498', '2563',
#        '2497', '2566', '2552', '2548', '2549', '2567', '2574', '2711', '2502',
#             0, '2503', '2547', '2570', '2539', '2572', '2496', '2504', '3841',
#        '2537', '3792', '2542', '3377', '2565', '3390', '2571', '2538', '3793',
#        '3838', '2550', '2569', '3794', '2562', '3795', '3513', '2540', '3797',
#        '2822', '2564', '3619', '3621', '2561', '3799', '2536', '3455', '2544',
#        '3292', '2568', '2541', '3687', '1007', '1008', '3291', '3684', '3293',
#        '#N/A', '3686', '3660', '2712', '2823', '2576', '3294', '3685', '2546',
#        '2545', '3635', '1006', '1002', '3464', '3790', '1003', '3381', '2500',
#        '3791', '3456', '1005', '1001'],
#       dtype='object')

# %%
# Number of station which have no checkout ID
blank_stations = len(df_bike_checkout_id_blank["Checkout Station"].value_counts())

# Number of Unique Checkout Station
unique_checkout_stations = df_bike_clean["Checkout Station"].unique().size

# Number of station with unique checkout station ids other than zero
unique_stations_nonnull = unique_checkout_stations - blank_stations 

# Number of Unique Checkout Station ID
unique_checkout_id = df_bike_clean["Checkout Station ID"].unique().size
unique_checkout_id_not_zero = unique_checkout_id - 2
## -2 for zero and #N/A checkout id


# Summary Checkout Station ID findings 
print(f"There are {blank_stations} stations without checkout ID.")
print(f"There are {unique_checkout_stations} Unique Checkout Station.")
print(f"There are {unique_stations_nonnull} stations with unique checkout station ids other than zero.")
print(f"There are {unique_checkout_id_not_zero} Unique Checkout Station ID.")
# Out:
# There are 24 stations without checkout ID.
# There are 104 Unique Checkout Station.
# There are 80 stations with unique checkout station ids other than zero.
# There are 83 Unique Checkout Station ID.

# %%
## we have more number of unique checkout station ids than number of unique checkout stations
## this implies we have few checkout station with more than one checkout station IDs

# creating a dictionary using keyword arguments checkout station and checkout station ids 
Checkout_station_id = dict()
for index, row in df_bike_na.iterrows():
    if row['Checkout Station'] not in Checkout_station_id:
        Checkout_station_id[row['Checkout Station']] = set()
    else:
         Checkout_station_id[row['Checkout Station']].add(row['Checkout Station ID'])

# %%
# To check which station has more than one checkout ids
Checkout_id_check = Checkout_station_id
for key in Checkout_id_check:
    if len(Checkout_id_check[key]) > 1:
        print("{} has both ids: {}".format(key, Checkout_id_check[key]))
# Out:
# Bullock Museum @ Congress & MLK has both ids: {'#N/A', '2538'}
# State Capitol @ 14th & Colorado has both ids: {'2541', '#N/A'}
# Main Office has both ids: {0, '1001', '#N/A'}
# Lavaca & 6th has both ids: {'1007', '3294'}
# Re-branding has both ids: {0, '#N/A'}
# Repair Shop has both ids: {0, '#N/A'}
# Republic Square @ 5th & Guadalupe has both ids: {'3456', '3455'}
# Dean Keeton & Speedway  has both ids: {'#N/A', '3794'}

# %%
#To check if there is a overlap of Checkout Station ID :

#Removing station with zero checkout station ID 
for key in Checkout_id_check:
    if 0 in Checkout_id_check[key]:
        Checkout_id_check[key].remove(0)

#Removing station with "#N/A" checkout station ID 
for key in Checkout_id_check:
    if "#N/A" in Checkout_id_check[key]:
        Checkout_id_check[key].remove("#N/A")
        
# checking for overlap of station ID
for key1 in Checkout_id_check:
    for key2 in Checkout_id_check:
        if key1 == key2:
            continue
        intersect = Checkout_id_check[key1].intersection(Checkout_id_check[key2])
        if len(intersect) > 0:
            print("{} and {} share id: {}".format(key1, key2, intersect))
# Out:
# Lavaca & 6th and Guadalupe & 6th share id: {'3294'}
# Republic Square @ Federal Courthouse Plaza and Republic Square @ 5th & Guadalupe share id: {'3455'}
# Guadalupe & 6th and Lavaca & 6th share id: {'3294'}
# Republic Square @ 5th & Guadalupe and Republic Square @ Federal Courthouse Plaza share id: {'3455'}

# %%
# Organize column and take columns with relevant data which we will use for analysis
df_bike_clean[["Trip ID", "Membership Type", "Checkout Date","Checkout Time", "Checkout Station", "Return Station", "Trip Duration Minutes", "Trip Month", "Trip Year","Trip Date", "Trip Day of Week", "Trip Hour"]]
# Out:
#            Trip ID                     Membership Type  \
# 0       9900285854        Annual (San Antonio B-cycle)
# 1       9900285855      24-Hour Kiosk (Austin B-cycle)
# 2       9900285856  Annual Membership (Austin B-cycle)
# 3       9900285857      24-Hour Kiosk (Austin B-cycle)
# 4       9900285858      24-Hour Kiosk (Austin B-cycle)
# 5       9900285859      24-Hour Kiosk (Austin B-cycle)
# 6       9900285860  Annual Membership (Austin B-cycle)
# 7       9900285861  Annual Membership (Austin B-cycle)
# 8       9900285862  Annual Membership (Austin B-cycle)
# 9       9900285863      24-Hour Kiosk (Austin B-cycle)
# 10      9900285864  Annual Membership (Austin B-cycle)
# 11      9900285865      24-Hour Kiosk (Austin B-cycle)
# 12      9900285866      24-Hour Kiosk (Austin B-cycle)
# 13      9900285867      24-Hour Kiosk (Austin B-cycle)
# 14      9900285868      24-Hour Kiosk (Austin B-cycle)
# 15      9900285869      24-Hour Kiosk (Austin B-cycle)
# 16      9900285870      24-Hour Kiosk (Austin B-cycle)
# 17      9900285871      24-Hour Kiosk (Austin B-cycle)
# 18      9900285872      24-Hour Kiosk (Austin B-cycle)
# 19      9900285873  Annual Membership (Austin B-cycle)
# 20      9900285874  Annual Membership (Austin B-cycle)
# 21      9900285875      24-Hour Kiosk (Austin B-cycle)
# 22      9900285876      24-Hour Kiosk (Austin B-cycle)
# 23      9900285877      24-Hour Kiosk (Austin B-cycle)
# 24      9900285878      24-Hour Kiosk (Austin B-cycle)
# 25      9900285879      24-Hour Kiosk (Austin B-cycle)
# 26      9900285880      24-Hour Kiosk (Austin B-cycle)
# 27      9900285881      24-Hour Kiosk (Austin B-cycle)
# 28      9900285882      24-Hour Kiosk (Austin B-cycle)
# 29      9900285883      24-Hour Kiosk (Austin B-cycle)
# ...            ...                                 ...
# 991241    18121783             U.T. Student Membership
# 991242    18121832                            Local365
# 991243    18121835             U.T. Student Membership
# 991244    18121846                            Local365
# 991245    18122031             U.T. Student Membership
# 991246    18122037             U.T. Student Membership
# 991247    18122044             U.T. Student Membership
# 991248    18122046             U.T. Student Membership
# 991249    18122117             U.T. Student Membership
# 991250    18122165             U.T. Student Membership
# 991251    18122169             U.T. Student Membership
# 991252    18122200                             Walk Up
# 991253    18122205                             Walk Up
# 991254    18122208                             Walk Up
# 991255    18122226                            Local365
# 991256    18122234                             Walk Up
# 991257    18122236                             Walk Up
# 991258    18122251             U.T. Student Membership
# 991259    18122254             U.T. Student Membership
# 991260    18122258                            Local365
# 991261    18122272             U.T. Student Membership
# 991262    18122273             U.T. Student Membership
# 991263    18122293             U.T. Student Membership
# 991264    18122298             U.T. Student Membership
# 991265    18122307             U.T. Student Membership
# 991266    18122309             U.T. Student Membership
# 991267    18122312                 Local365+Guest Pass
# 991268    18122330             U.T. Student Membership
# 991269    18122340             U.T. Student Membership
# 991270    18122349             U.T. Student Membership
#
#                   Checkout Date Checkout Date Checkout Time  \
# 0       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 1       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 2       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 3       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 4       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 5       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 6       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 7       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 8       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 9       2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 10      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 11      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 12      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 13      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 14      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 15      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 16      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 17      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 18      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 19      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 20      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 21      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 22      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 23      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 24      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 25      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 26      2014-10-26T00:00:00.000    2014-10-26      13:12:00
# 27      2014-10-26T00:00:00.000    2014-10-26      14:12:00
# 28      2014-10-26T00:00:00.000    2014-10-26      14:12:00
# 29      2014-10-26T00:00:00.000    2014-10-26      14:12:00
# ...                         ...           ...           ...
# 991241  2018-07-31T00:00:00.000    2018-07-31      21:17:56
# 991242  2018-07-31T00:00:00.000    2018-07-31      21:23:35
# 991243  2018-07-31T00:00:00.000    2018-07-31      21:23:57
# 991244  2018-07-31T00:00:00.000    2018-07-31      21:26:58
# 991245  2018-07-31T00:00:00.000    2018-07-31      22:03:35
# 991246  2018-07-31T00:00:00.000    2018-07-31      22:04:27
# 991247  2018-07-31T00:00:00.000    2018-07-31      22:05:54
# 991248  2018-07-31T00:00:00.000    2018-07-31      22:06:07
# 991249  2018-07-31T00:00:00.000    2018-07-31      22:24:46
# 991250  2018-07-31T00:00:00.000    2018-07-31      22:34:09
# 991251  2018-07-31T00:00:00.000    2018-07-31      22:34:37
# 991252  2018-07-31T00:00:00.000    2018-07-31      22:41:32
# 991253  2018-07-31T00:00:00.000    2018-07-31      22:43:01
# 991254  2018-07-31T00:00:00.000    2018-07-31      22:43:51
# 991255  2018-07-31T00:00:00.000    2018-07-31      22:50:37
# 991256  2018-07-31T00:00:00.000    2018-07-31      22:54:25
# 991257  2018-07-31T00:00:00.000    2018-07-31      22:55:24
# 991258  2018-07-31T00:00:00.000    2018-07-31      23:00:35
# 991259  2018-07-31T00:00:00.000    2018-07-31      23:01:53
# 991260  2018-07-31T00:00:00.000    2018-07-31      23:04:23
# 991261  2018-07-31T00:00:00.000    2018-07-31      23:07:37
# 991262  2018-07-31T00:00:00.000    2018-07-31      23:08:37
# 991263  2018-07-31T00:00:00.000    2018-07-31      23:17:40
# 991264  2018-07-31T00:00:00.000    2018-07-31      23:20:17
# 991265  2018-07-31T00:00:00.000    2018-07-31      23:24:24
# 991266  2018-07-31T00:00:00.000    2018-07-31      23:24:32
# 991267  2018-07-31T00:00:00.000    2018-07-31      23:29:21
# 991268  2018-07-31T00:00:00.000    2018-07-31      23:39:16
# 991269  2018-07-31T00:00:00.000    2018-07-31      23:42:50
# 991270  2018-07-31T00:00:00.000    2018-07-31      23:44:32
#
#                                          Checkout Station  \
# 0                                          West & 6th St.
# 1                 Convention Center / 4th St. @ MetroRail
# 2                                          West & 6th St.
# 3       Zilker Park at Barton Springs & William Barton...
# 4                         Bullock Museum @ Congress & MLK
# 5       Zilker Park at Barton Springs & William Barton...
# 6                                          8th & Congress
# 7                              East 11th St. & San Marcos
# 8                                          8th & Congress
# 9       Zilker Park at Barton Springs & William Barton...
# 10                             South Congress & Elizabeth
# 11                          Pfluger Bridge @ W 2nd Street
# 12                                   Riverside @ S. Lamar
# 13                                         2nd & Congress
# 14                             South Congress & Elizabeth
# 15                             South Congress & Elizabeth
# 16                                   Riverside @ S. Lamar
# 17                                   Riverside @ S. Lamar
# 18                       Convention Center/ 3rd & Trinity
# 19                            East 6th at Robert Martinez
# 20                              East 6th & Pedernales St.
# 21                                 Davis at Rainey Street
# 22                                 Davis at Rainey Street
# 23                                 Davis at Rainey Street
# 24                               UT West Mall @ Guadalupe
# 25                      East 11th Street at Victory Grill
# 26                          Pfluger Bridge @ W 2nd Street
# 27                               UT West Mall @ Guadalupe
# 28                               UT West Mall @ Guadalupe
# 29                                   Riverside @ S. Lamar
# ...                                                   ...
# 991241                                  23rd & Rio Grande
# 991242                               Riverside @ S. Lamar
# 991243                                       22nd & Pearl
# 991244                               21st & Speedway @PCL
# 991245                               21st & Speedway @PCL
# 991246                                  21st & University
# 991247                               21st & Speedway @PCL
# 991248                               21st & Speedway @PCL
# 991249                                  Rio Grande & 28th
# 991250                               21st & Speedway @PCL
# 991251                               21st & Speedway @PCL
# 991252                                        Zilker Park
# 991253                                       Brazos & 6th
# 991254                                       Brazos & 6th
# 991255                  Convention Center / 3rd & Trinity
# 991256                          East 6th & Pedernales St.
# 991257                          East 6th & Pedernales St.
# 991258                                  23rd & Rio Grande
# 991259                                  23rd & Rio Grande
# 991260                             Red River & 8th Street
# 991261                                       22nd & Pearl
# 991262                                       22nd & Pearl
# 991263                                       22nd & Pearl
# 991264                                  23rd & Rio Grande
# 991265                  Capitol Station / Congress & 11th
# 991266                  Capitol Station / Congress & 11th
# 991267                Long Center @ South 1st & Riverside
# 991268                                  Rio Grande & 28th
# 991269                               Dean Keeton & Whitis
# 991270                                  Rio Grande & 28th
#
#                                            Return Station  \
# 0                                    Rainey St @ Cummings
# 1                           Pfluger Bridge @ W 2nd Street
# 2                                          8th & Congress
# 3       Zilker Park at Barton Springs & William Barton...
# 4                        Convention Center/ 3rd & Trinity
# 5                                 ACC - Rio Grande & 12th
# 6       State Capitol Visitors Garage @ San Jacinto & ...
# 7                                City Hall / Lavaca & 2nd
# 8                                          8th & Congress
# 9                                 ACC - Rio Grande & 12th
# 10                                         8th & Congress
# 11                       Convention Center/ 3rd & Trinity
# 12                                   Riverside @ S. Lamar
# 13                               South Congress & Academy
# 14                                       17th & Guadalupe
# 15                                       17th & Guadalupe
# 16                                   Riverside @ S. Lamar
# 17                                   Riverside @ S. Lamar
# 18                    Long Center @ South 1st & Riverside
# 19                              East 6th & Pedernales St.
# 20                            East 6th at Robert Martinez
# 21                                   Rainey St @ Cummings
# 22                                   Rainey St @ Cummings
# 23                                   Rainey St @ Cummings
# 24                               UT West Mall @ Guadalupe
# 25                                       Guadalupe & 21st
# 26                                    Barton Springs Pool
# 27                               City Hall / Lavaca & 2nd
# 28                               City Hall / Lavaca & 2nd
# 29                                   Riverside @ S. Lamar
# ...                                                   ...
# 991241                                  Rio Grande & 28th
# 991242                               Riverside @ S. Lamar
# 991243                                       22nd & Pearl
# 991244                               21st & Speedway @PCL
# 991245                                  23rd & Rio Grande
# 991246                                      Nueces & 26th
# 991247                                  23rd & Rio Grande
# 991248                                      Nueces & 26th
# 991249                                  Rio Grande & 28th
# 991250                               21st & Speedway @PCL
# 991251                               Dean Keeton & Whitis
# 991252                                        Zilker Park
# 991253                  Republic Square @ 5th & Guadalupe
# 991254                  Republic Square @ 5th & Guadalupe
# 991255                          East 6th & Pedernales St.
# 991256                        East 6th at Robert Martinez
# 991257                        East 6th at Robert Martinez
# 991258                               21st & Speedway @PCL
# 991259                               21st & Speedway @PCL
# 991260                                 11th & San Jacinto
# 991261                                         3rd & West
# 991262                               21st & Speedway @PCL
# 991263                                       22nd & Pearl
# 991264                                  23rd & Rio Grande
# 991265                           City Hall / Lavaca & 2nd
# 991266                           City Hall / Lavaca & 2nd
# 991267                          East 6th & Pedernales St.
# 991268                                       22nd & Pearl
# 991269                                      Nueces & 26th
# 991270                                  Rio Grande & 28th
#
#         Trip Duration Minutes Trip Month Trip Year  Trip Date  \
# 0                          76         10      2014         26
# 1                          58         10      2014         26
# 2                           8         10      2014         26
# 3                          28         10      2014         26
# 4                          15         10      2014         26
# 5                          26         10      2014         26
# 6                          35         10      2014         26
# 7                          11         10      2014         26
# 8                           0         10      2014         26
# 9                          25         10      2014         26
# 10                         10         10      2014         26
# 11                         29         10      2014         26
# 12                         34         10      2014         26
# 13                         12         10      2014         26
# 14                         37         10      2014         26
# 15                         37         10      2014         26
# 16                         50         10      2014         26
# 17                         49         10      2014         26
# 18                         20         10      2014         26
# 19                          2         10      2014         26
# 20                         21         10      2014         26
# 21                         41         10      2014         26
# 22                         41         10      2014         26
# 23                         40         10      2014         26
# 24                         28         10      2014         26
# 25                         23         10      2014         26
# 26                         12         10      2014         26
# 27                         14         10      2014         26
# 28                         14         10      2014         26
# 29                         96         10      2014         26
# ...                       ...        ...       ...        ...
# 991241                      4        NaN       NaN         31
# 991242                     13        NaN       NaN         31
# 991243                     35        NaN       NaN         31
# 991244                     58        NaN       NaN         31
# 991245                     12        NaN       NaN         31
# 991246                      6        NaN       NaN         31
# 991247                     10        NaN       NaN         31
# 991248                     10        NaN       NaN         31
# 991249                     19        NaN       NaN         31
# 991250                      0        NaN       NaN         31
# 991251                      6        NaN       NaN         31
# 991252                     12        NaN       NaN         31
# 991253                     40        NaN       NaN         31
# 991254                     40        NaN       NaN         31
# 991255                     14        NaN       NaN         31
# 991256                     26        NaN       NaN         31
# 991257                     25        NaN       NaN         31
# 991258                      7        NaN       NaN         31
# 991259                      7        NaN       NaN         31
# 991260                      3        NaN       NaN         31
# 991261                     11        NaN       NaN         31
# 991262                      3        NaN       NaN         31
# 991263                      4        NaN       NaN         31
# 991264                      1        NaN       NaN         31
# 991265                     29        NaN       NaN         31
# 991266                     29        NaN       NaN         31
# 991267                     18        NaN       NaN         31
# 991268                      4        NaN       NaN         31
# 991269                      2        NaN       NaN         31
# 991270                      4        NaN       NaN         31
#
#        Trip Day of Week  Trip Hour
# 0                Sunday         13
# 1                Sunday         13
# 2                Sunday         13
# 3                Sunday         13
# 4                Sunday         13
# 5                Sunday         13
# 6                Sunday         13
# 7                Sunday         13
# 8                Sunday         13
# 9                Sunday         13
# 10               Sunday         13
# 11               Sunday         13
# 12               Sunday         13
# 13               Sunday         13
# 14               Sunday         13
# 15               Sunday         13
# 16               Sunday         13
# 17               Sunday         13
# 18               Sunday         13
# 19               Sunday         13
# 20               Sunday         13
# 21               Sunday         13
# 22               Sunday         13
# 23               Sunday         13
# 24               Sunday         13
# 25               Sunday         13
# 26               Sunday         13
# 27               Sunday         14
# 28               Sunday         14
# 29               Sunday         14
# ...                 ...        ...
# 991241          Tuesday         21
# 991242          Tuesday         21
# 991243          Tuesday         21
# 991244          Tuesday         21
# 991245          Tuesday         22
# 991246          Tuesday         22
# 991247          Tuesday         22
# 991248          Tuesday         22
# 991249          Tuesday         22
# 991250          Tuesday         22
# 991251          Tuesday         22
# 991252          Tuesday         22
# 991253          Tuesday         22
# 991254          Tuesday         22
# 991255          Tuesday         22
# 991256          Tuesday         22
# 991257          Tuesday         22
# 991258          Tuesday         23
# 991259          Tuesday         23
# 991260          Tuesday         23
# 991261          Tuesday         23
# 991262          Tuesday         23
# 991263          Tuesday         23
# 991264          Tuesday         23
# 991265          Tuesday         23
# 991266          Tuesday         23
# 991267          Tuesday         23
# 991268          Tuesday         23
# 991269          Tuesday         23
# 991270          Tuesday         23
#
# [991271 rows x 13 columns]

# %% [markdown]
# ## Cleaning and Groupping Membership Data
#
# While there are missing values in the membership data, we want to take a closer look to understand the types of memberships. Upon closer inspection there are memberships with similar names that should be categorized together. For example: U.T. Student Membership and UT Student Membership. Furthermore, it will be more helpful to categorize the data by day, weekend, week, month, year, 3 year, and student memberships.
#
# But we are not dropping the rows because even in these rows the Trip IDs are correct
# which we can use to count number of rides made for our analysis for other columns

# %%
df_bike_clean["Membership Type"].value_counts()
# Out:
# Walk Up                                          368322
# Local365                                         167363
# U.T. Student Membership                          158480
# 24-Hour Kiosk (Austin B-cycle)                   108672
# Local30                                           54774
# Weekender                                         43880
# Annual Membership (Austin B-cycle)                30306
# Explorer                                          14860
# Local365+Guest Pass                               10331
# Local365 ($80 plus tax)                            4005
# Founding Member                                    3550
# 7-Day                                              3137
# Founding Member (Austin B-cycle)                   2764
# 7-Day Membership (Austin B-cycle)                  2760
# Semester Membership (Austin B-cycle)               2426
# Annual                                             1087
# Semester Membership                                 900
# Local30 ($11 plus tax)                              840
# 24-Hour-Online (Austin B-cycle)                     737
# Weekender ($15 plus tax)                            566
# Try Before You Buy Special                          522
# Annual Member                                       480
# Annual Membership                                   441
# Annual (San Antonio B-cycle)                        402
# RideScout Single Ride                               398
# ACL Weekend Pass Special (Austin B-cycle)           329
# Annual Member (Houston B-cycle)                     296
# Annual Membership (Fort Worth Bike Sharing)         266
# Annual (Denver B-cycle)                             232
# Republic Rider (Annual)                             216
# Explorer ($8 plus tax)                              186
# Annual Plus                                         181
# Annual (Madison B-cycle)                            165
# Annual (Broward B-cycle)                            142
# Annual (Denver Bike Sharing)                        131
# Annual (Boulder B-cycle)                            129
# Local365 Youth with helmet (age 13-17 riders)        97
# Local365 Youth (age 13-17 riders)                    92
# Annual Membership (GREENbike)                        71
# Annual Pass                                          54
# Annual (Cincy Red Bike)                              51
# Annual (Kansas City B-cycle)                         51
# Madtown Monthly                                      36
# Aluminum Access                                      30
# Annual (Nashville B-cycle)                           27
# FunFunFun Fest 3 Day Pass                            27
# Annual Plus Membership                               25
# Annual Membership (Charlotte B-cycle)                22
# Annual                                               18
# Republic Rider                                       17
# Membership: pay once  one-year commitment            15
# RESTRICTED                                           10
# Denver B-cycle Founder                               10
# Annual Membership (Indy - Pacers Bikeshare )         10
# UT Student Membership                                 9
# PROHIBITED                                            8
# Annual (Omaha B-cycle)                                3
# 24-Hour Membership (Austin B-cycle)                   1
# Name: Membership Type, dtype: int64

# %%
# Examine Prohibited and Restricted
test = df_bike_clean.loc[df_bike_clean["Membership Type"] == "RESTRICTED", :]
#test = df_bike_clean.loc[df_bike_clean["Membership Type"] == "PROHIBITED", :]
test.head()
# Out:
#        Bicycle ID            Checkout Date                   Checkout Station  \
# 326221        158  2016-01-20T00:00:00.000  Capitol Station / Congress & 11th
# 329490        421  2016-01-11T00:00:00.000  Capitol Station / Congress & 11th
# 329491        407  2016-01-11T00:00:00.000  Capitol Station / Congress & 11th
# 329492        407  2016-01-11T00:00:00.000  Capitol Station / Congress & 11th
# 329493        407  2016-01-11T00:00:00.000  Capitol Station / Congress & 11th
#
#        Checkout Station ID Checkout Time Membership Type Trip Month  \
# 326221                2497      15:35:09      RESTRICTED          1
# 329490                2497      11:30:08      RESTRICTED          1
# 329491                2497      14:12:09      RESTRICTED          1
# 329492                2497      14:13:32      RESTRICTED          1
# 329493                2497      14:13:50      RESTRICTED          1
#
#                            Return Station Return Station ID  \
# 326221  Capitol Station / Congress & 11th              2497
# 329490  Capitol Station / Congress & 11th              2497
# 329491  Capitol Station / Congress & 11th              2497
# 329492  Capitol Station / Congress & 11th              2497
# 329493  Capitol Station / Congress & 11th              2497
#
#         Trip Duration Minutes  Trip ID Trip Year Checkout Date  Year  Month  \
# 326221                      0  8482474      2016    2016-01-20  2016      1
# 329490                      8  8368765      2016    2016-01-11  2016      1
# 329491                      1  8370726      2016    2016-01-11  2016      1
# 329492                      0  8370745      2016    2016-01-11  2016      1
# 329493                      1  8370747      2016    2016-01-11  2016      1
#
#         Trip Date Trip Day of Week  Trip Hour
# 326221         20        Wednesday         15
# 329490         11           Monday         11
# 329491         11           Monday         14
# 329492         11           Monday         14
# 329493         11           Monday         14

# %%
# Replace all 24-hour with same name == day 
df_bike_clean["Membership Type"] = df_bike_clean["Membership Type"].replace(
    {"24-Hour Kiosk (Austin B-cycle)": "day",
     "24-Hour-Online (Austin B-cycle)": "day",
     "24-Hour Membership (Austin B-cycle)": "day",
    "Explorer": "day", 
    "Explorer ($8 plus tax)":"day",
    "Walk Up": "day",
    "Try Before You Buy Special": "day",
    "RideScout Single Ride": "day", 
    "Aluminum Access":"day"})

# Replace all weekend membership == weekend 
df_bike_clean["Membership Type"] = df_bike_clean["Membership Type"].replace(
    {
        "Weekender": "weekend", 
        "Weekender ($15 plus tax)": "weekend", 
        "ACL Weekend Pass Special (Austin B-cycle)": "weekend", 
        "FunFunFun Fest 3 Day Pass": "weekend"
    })

# Replace all weekend membership == week
df_bike_clean["Membership Type"] = df_bike_clean["Membership Type"].replace(
    {
        "7-Day": "week", 
        "7-Day Membership (Austin B-cycle)": "week", 
    })


# Replace all weekend membership == month
df_bike_clean["Membership Type"] = df_bike_clean["Membership Type"].replace(
    {
        "Local30": "month", 
        "Local30 ($11 plus tax)": "month",
        "Madtown Monthly":"month", 
    })


# Combine all student memberships
df_bike_clean["Membership Type"] = df_bike_clean["Membership Type"].replace(
    {
        "U.T. Student Membership": "student",
        "UT Student Membership": "student", 
        "Semester Membership (Austin B-cycle)":"student", 
        "Semester Membership": "student"
    })

# Replace all annual membership == year
df_bike_clean["Membership Type"] = df_bike_clean["Membership Type"].replace(
    {
        "Annual Membership (Austin B-cycle)": "year",
         "Annual Member": "year",
         "Annual Membership":"year",
         "Annual (San Antonio B-cycle)": "year",
         "Annual Member (Houston B-cycle)":"year",
         "Annual Membership (Fort Worth Bike Sharing)":"year",
         "Annual (Denver B-cycle)":"year",
         "Republic Rider (Annual)":"year",
         "Republic Rider": "year",
         "Annual Plus":"year",
         "Annual (Madison B-cycle)":"year",
         "Annual (Broward B-cycle)":"year",
         "Annual (Denver Bike Sharing)":"year",
         "Annual (Boulder B-cycle)":"year",
         "Annual Membership (GREENbike)":"year",
         "Annual Pass":"year",
         "Annual (Kansas City B-cycle)":"year",
         "Annual (Cincy Red Bike)":"year",
         "Annual (Nashville B-cycle)":"year",
         "Annual Plus Membership":"year",
         "Annual Membership (Charlotte B-cycle)":"year",
         "Annual Membership (Indy - Pacers Bikeshare )":"year",
         "Annual (Omaha B-cycle)":"year",
         "Annual":"year",
         "Annual ": "year",
         "Local365": "year", 
         "Local365+Guest Pass":"year",
         "Local365 ($80 plus tax)": "year",
         "Local365 Youth with helmet (age 13-17 riders)": "year", 
         "Local365 Youth (age 13-17 riders)":"year",
         "Membership: pay once  one-year commitment":"year"
        
    })

# Replace all founding membership == 3 year
df_bike_clean["Membership Type"] = df_bike_clean["Membership Type"].replace(
    {
        "Founding Member": "3 year",
        "Founding Member (Austin B-cycle)": "3 year",
        "Denver B-cycle Founder": "3 year"
    })

# %%
# Create a new data frame that does not include restricted and prohibited
bike_trips= df_bike_clean.loc[(df_bike_clean["Membership Type"] != "RESTRICTED") & (df_bike_clean["Membership Type"] != "PROHIBITED"), :]

# %%
# Verify clean up 
bike_trips["Membership Type"].value_counts()
# Out:
# day        493728
# year       216726
# student    161815
# month       55650
# weekend     44802
# 3 year       6324
# week         5897
# Name: Membership Type, dtype: int64

# %%
# Filling the na values  
df_bike_clean = df_bike_clean.fillna(0)
df_bike_clean.count()
# Out:
# Bicycle ID               991271
# Checkout Date            991271
# Checkout Station         991271
# Checkout Station ID      991271
# Checkout Time            991271
# Membership Type          991271
# Trip Month               991271
# Return Station           991271
# Return Station ID        991271
# Trip Duration Minutes    991271
# Trip ID                  991271
# Trip Year                991271
# Checkout Date            991271
# Year                     991271
# Month                    991271
# Trip Date                991271
# Trip Day of Week         991271
# Trip Hour                991271
# dtype: int64

# %%
# Export to csv
df_bike_clean.to_csv("Clean_Data\out.csv", index = None)
